# %% [markdown]
# Source:
#
# Provide the names, email addresses, institutions, and other contact information of the donors and creators of the data set.The original dataset version was collected by Tanvir Ahmad, Assia Munir, Sajjad Haider Bhatti, Muhammad Aftab, and Muhammad Ali Raza (Government College University, Faisalabad, Pakistan) and made available by them on FigShare under the Attribution 4.0 International (CC BY 4.0: freedom to share and adapt the material) copyright in July 2017.
#
# The current version of the dataset was elaborated by Davide Chicco (Krembil Research Institute, Toronto, Canada) and donated to the University of California Irvine Machine Learning Repository under the same Attribution 4.0 International (CC BY 4.0) copyright in January 2020. Davide Chicco can be reached at <davidechicco '@' davidechicco.it>
#
#
#
# https://archive.ics.uci.edu/ml/datasets/Heart+failure+clinical+records

# %% [markdown]
# Attribute Information:
#
# Thirteen (13) clinical features:
#
# - age: age of the patient (years)
# - anaemia: decrease of red blood cells or hemoglobin (boolean)
# - high blood pressure: if the patient has hypertension (boolean)
# - creatinine phosphokinase (CPK): level of the CPK enzyme in the blood (mcg/L)
# - diabetes: if the patient has diabetes (boolean)
# - ejection fraction: percentage of blood leaving the heart at each contraction (percentage)
# - platelets: platelets in the blood (kiloplatelets/mL)
# - sex: woman or man (binary)
# - serum creatinine: level of serum creatinine in the blood (mg/dL)
# - serum sodium: level of serum sodium in the blood (mEq/L)
# - smoking: if the patient smokes or not (boolean)
# - time: follow-up period (days)
# - [target] death event: if the patient deceased during the follow-up period (boolean)

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../../DataSets/heart_failure_clinical_records_dataset.csv')
df.head(2)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1

# %%
df.shape
# Out:
# (299, 13)

# %%
sns.pairplot(data=df[['age', 'creatinine_phosphokinase', 'platelets', 'serum_creatinine', 'serum_sodium', 'DEATH_EVENT']], hue='DEATH_EVENT');

# %%
df.head(2)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1

# %%
df.groupby()

# %%
print('Probability of a female death:')
prob_fem_d = df[df['DEATH_EVENT']==1]['sex'].value_counts()[0]/df['sex'].value_counts()[0]
print(prob_fem_d)
# Out:
# Probability of a female death:
# 0.3238095238095238

# %%
print('Probability of a male death:')
prob_mal_d = df[df['DEATH_EVENT']==1]['sex'].value_counts()[1]/df['sex'].value_counts()[1]
print(prob_mal_d)
# Out:
# Probability of a male death:
# 0.31958762886597936

# %%
print('Difference in percents:')
(1 - prob_mal_d/prob_fem_d)*100
# Out:
# Difference in percents:
# 1.303820497271091

# %%
print('Probability of a smoker death:')
prob_smok_death = df[df['DEATH_EVENT']==1]['smoking'].value_counts()[1]/df['smoking'].value_counts()[1]
print(prob_smok_death)
# Out:
# Probability of a smoker death:
# 0.3125

# %%
print('Probability of a non-smoker death:')
prob_nonsmok_death = df[df['DEATH_EVENT']==1]['smoking'].value_counts()[0]/df['smoking'].value_counts()[0]
print(prob_nonsmok_death)
# Out:
# Probability of a non-smoker death:
# 0.3251231527093596

# %%
print('Difference in percents:')
(1 - prob_smok_death/prob_nonsmok_death)*100
# Out:
# Difference in percents:
# 3.882575757575757

# %%
print('Probability of surveillance for high pressure patients:')
prob_high_press_surv = df[df['DEATH_EVENT']==0]['high_blood_pressure'].value_counts()[1]/df['high_blood_pressure'].value_counts()[1]
print(prob_high_press_surv)
# Out:
# Probability of surveillance for high pressure patients:
# 0.6285714285714286

# %%
print('Probability of death for patients with high pressure:')
prob_high_press_death = df[df['DEATH_EVENT']==1]['high_blood_pressure'].value_counts()[1]/df['high_blood_pressure'].value_counts()[1]
print(prob_high_press_death)
# Out:
# Probability of death for patients with high pressure:
# 0.37142857142857144

# %%
print('Probability of death for patients without high pressure:')
prob_no_high_press_death = df[df['DEATH_EVENT']==1]['high_blood_pressure'].value_counts()[0]/df['high_blood_pressure'].value_counts()[0]
print(prob_no_high_press_death)
# Out:
# Probability of death for patients without high pressure:
# 0.29381443298969073

# %%
print('Difference in percents:')
(1 - prob_no_high_press_death/prob_high_press_death)*100, prob_no_high_press_death/prob_high_press_death
# Out:
# Difference in percents:
# (20.89611419508327, 0.7910388580491673)

# %% [markdown]
# People with high pressure die more often

# %%
print('Probability of death for patients without diabetes is:')
prob_diab_death = df[df['DEATH_EVENT']==1]['diabetes'].value_counts()[1]/df['diabetes'].value_counts()[1]
print(prob_diab_death)
# Out:
# Probability of death for patients without diabetes is:
# 0.32

# %%
print('Probability of death for patients with diabetes is:')
prob_diab_death = df[df['DEATH_EVENT']==1]['diabetes'].value_counts()[0]/df['diabetes'].value_counts()[0]
print(prob_diab_death)
# Out:
# Probability of death for patients with diabetes is:
# 0.3218390804597701

# %%
print('Difference in percents:')
(1 - prob_diab_death/prob_diab_death)*100
# Out:
# Difference in percents:
# 0.0

# %% [markdown]
# There is no clear influence of diabete on the patiences death.

# %%
df.columns
# Out:
# Index(['age', 'anaemia', 'creatinine_phosphokinase', 'diabetes',
#        'ejection_fraction', 'high_blood_pressure', 'platelets',
#        'serum_creatinine', 'serum_sodium', 'sex', 'smoking', 'time',
#        'DEATH_EVENT'],
#       dtype='object')

# %%
print('Probability of death for patients without anaemia is:')
prob_anaemia_death = df[df['DEATH_EVENT']==1]['anaemia'].value_counts()[0]/df['anaemia'].value_counts()[0]
print(prob_anaemia_death)
# Out:
# Probability of death for patients without anaemia is:
# 0.29411764705882354

# %%
print('Probability of death for patients without anaemia is:')
prob_anaemia_surv = df[df['DEATH_EVENT']==1]['anaemia'].value_counts()[1]/df['anaemia'].value_counts()[1]
print(prob_anaemia_surv)
# Out:
# Probability of death for patients without anaemia is:
# 0.35658914728682173

# %%
print('Difference in percents:')
(1 - prob_anaemia_death/prob_anaemia_surv)*100
# Out:
# Difference in percents:
# 17.519181585677757

# %% [markdown]
# Patients with anaemia die more often

# %%
df.head(3)
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1

# %%
fig, [[ax1, ax2], [ax3, ax4], [ax5, ax6]] = plt.subplots(3, 2, figsize=(16, 16))

sns.histplot(data=df, x='age', hue='DEATH_EVENT', ax=ax1, bins=20, 
             alpha=0.5, kde=True, palette='coolwarm')

sns.histplot(data=df, x='creatinine_phosphokinase', hue='DEATH_EVENT', ax=ax2, bins=20,
             alpha=0.5, kde=True, palette='coolwarm', log_scale=True)

sns.histplot(data=df, x='ejection_fraction', hue='DEATH_EVENT', ax=ax3, bins=20, 
             alpha=0.5, kde=True, palette='coolwarm')

sns.histplot(data=df, x='platelets', hue='DEATH_EVENT', ax=ax4, bins=20, 
             alpha=0.5, kde=True, palette='coolwarm')

sns.histplot(data=df, x='serum_creatinine', hue='DEATH_EVENT', ax=ax5, bins=20, 
             alpha=0.5, kde=True, palette='coolwarm', log_scale=True)

sns.histplot(data=df, x='serum_sodium', hue='DEATH_EVENT', ax=ax6, bins=20, 
             alpha=0.5, kde=True, palette='coolwarm')

# %% [markdown]
# # Split Dataset

# %%
X = df[['high_blood_pressure', 'anaemia', 'serum_creatinine', 'age', 'serum_sodium', 'ejection_fraction']]
y = df['DEATH_EVENT']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# # Predictions:

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # LogisticRegression

# %%
log_regr = LogisticRegression(max_iter=1000)

# %%
log_regr.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
log_regr_prediction = log_regr.predict(X_test)

# %%
print(classification_report(y_test, log_regr_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.90      0.85        62
#            1       0.71      0.54      0.61        28
#
#     accuracy                           0.79        90
#    macro avg       0.76      0.72      0.73        90
# weighted avg       0.78      0.79      0.78        90

# %% [markdown]
# # Random forest:

# %%
rand_for = RandomForestClassifier(n_estimators=200)

# %%
rand_for.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=200)

# %%
rand_for_prediction = rand_for.predict(X_test)

# %%
print(classification_report(y_test, rand_for_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.81        62
#            1       0.59      0.61      0.60        28
#
#     accuracy                           0.74        90
#    macro avg       0.70      0.71      0.70        90
# weighted avg       0.75      0.74      0.75        90
